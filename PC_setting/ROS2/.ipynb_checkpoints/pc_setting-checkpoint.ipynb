# %% [markdown]
# # ROS2 PC setting

# %% [markdown]
# sudo apt update
#
# #### 터미널 창
# sudo apt install terminator
# #### ctrl + shift + e : 가로분할, w : 창 닫기, O, : 세로분할
#
# sudo apt update
# sudo apt upgrade
#
# #### 확인 : error가 아니라면 정상
# wget -V
#
# #### chrome 설치
# #### chrome 사이트에서 다운로드
# cd ~/Downloads/
# sudo dpkg -i <download file>
# #### chrome을 default web browser로 설정
#
# #### python 가상 환경 설치
# pip3 -V  # 없다면 설치
# sudo apt install python3-pip
# pip3 install --upgrade pip
#
# #### python 가상환경 설정 (venv 이용)
# mkdir venv
# #### ls로 파일 생성 여부 확인
# sudo apt install python3.10-venv
# python3 -m venv ~/venv/aris4
# #### 가상환경 설치 완료
#
# #### python 가상환경 실행
# source ~/venv/aris4/bin/activate
# #### 가상환경 종료
# deactivate
#
# #### workspace 생성
# mkdir aris4_ws
# #확인
# ls
#
# #### jupyter notebook 설치
# pip install jupyter
# #### 실행(원하는 파일 위치)
# jupyter notebook .
#
# #### *.ipylb 파일(markdown) 형식 *.md 변환 방법
# jupyter nbconvert --to markdown [변환할 노트북 파일명].ipynb
#
# #### VS code 설치
# #### code 사이트에서 다운로드
# cd ~/Downloads/
# sudo apt install <download file>
# cd ~/aris4_ws
# #### 현 경로 기준 code 실행
# code .
# #### extention에서 Python, jupyter, ros 설치
# #### ctrl + shift + p 후 python: select interpreter 입력 후 선택
# #### Enter interpreter path... 선택 후 ros2/venv/aris4/bin/python3 선택
# #### 해당 가상환경의 python으로 실행
#
# #### sublime text 설치
# #### 사이트에서 다운로드 or 하위 실행
# wget -qO - https://download.sublimetext.com/sublimehq-pub.gpg | gpg --dearmor | sudo tee /etc/apt/trusted.gpg.d/sublimehq-archive.gpg > /dev/null
# echo "deb https://download.sublimetext.com/ apt/stable/" | sudo tee /etc/apt/sources.list.d/sublime-text.list
# sudo apt-get update
# sudo apt-get install sublime-text
# #### 테스트
# subl .
#
# #### ROS2 설치
# #### ros2 humble 페이지에서 installation을 따라 작업 수행
#
# #### bashrc 설정 (단축어 설정)
# subl ~/.bashrc
# #### 제일 마지막 줄에 하위 3줄 추가
# alias sb="source ~/.bashrc; echo \"bashrc is reloaded\""
# alias ros_domain="export ROS_DOMAIN_ID=12; echo \"ROS_DOMAIN_ID=12\""
# alias humble="source ~/opt/ros/humble/setup.bash; ros_domain; echo \"ROS2 humble is activated\""
#
# #### Github 연동
# sudo apt install git-all
# #### vs code 내 연동
# code .
# #### 좌측의 source control 창에 open repository
# #### ctrl + shift + p 후 clone github
# #### ws directory에 연동
# #### extensions 에서 git graph 설치
#
#
# #### package build를 위한 colcon 설치 (colcon build 사이트 접속)
# sudo apt install python3-colcon-common-extensions
#
# #### 기타 (build 중 필요)
# pip install empy==3.3.4
# pip install libvirt-python
# pip install catkin_pkg
# pip install lark
# pip list | grep setuptools  # --> version 확인 후 다운그레이드
# pip install grep setuptools==58.2.0
#
# #sudo apt install python3-rosdep2
# #rosdep update
#
# #### package build 방법
# #### 1. 해당 ws 이동하여 전체 패키지 빌드
# clocon build
# #### 2. 해당 ws 이동하여 전체 패키지 실시간 빌드
# colcon build --symlink-install
#
# #### ~/.bashrc 파일 수정
# subl ~/.bashrc
# #### 하단에 하위 라인 추가 (파일 빌드 후 적용하기 위함)
# alias humble="source ~/opt/ros/humble/setup.bash; ros_domain; echo \"ROS2 humble is activated\" source /usr/share/colcon_argcomplete/hook/colcon-argcomplete.bash"
# alias rospy="source ~/venv/aris4/bin/activate; echo \"python3-ros activated\""
# 		alias aris="source ~/aris4_ws/aris-v4.0/install/setup.bash"
#
#
# pip install numpy
#
#
#
#
#
#
#
# #정상 build 확인 방법
# cd install/<package>/<node> # 파일 구조 동일한지 확인
#
# pip install serial  # 시리얼 통신
